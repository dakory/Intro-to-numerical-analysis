# %% [markdown]
# ## In a give notebook i will estimate machine epsilon

# %%
eps = 1.0
i = 0
while 1 + eps != 1:
    print(f"{i}: {eps}")
    eps/=1.1
    i+=1
# Out:
# 0: 1.0
# 1: 0.9090909090909091
# 2: 0.8264462809917354
# 3: 0.7513148009015777
# 4: 0.6830134553650705
# 5: 0.6209213230591549
# 6: 0.5644739300537771
# 7: 0.5131581182307065
# 8: 0.4665073802097331
# 9: 0.4240976183724846
# 10: 0.3855432894295314
# 11: 0.35049389948139215
# 12: 0.31863081771035645
# 13: 0.2896643797366877
# 14: 0.2633312543060797
# 15: 0.23939204936916333
# 16: 0.21762913579014848
# 17: 0.19784466890013497
# 18: 0.17985878990921358
# 19: 0.1635079908265578
# 20: 0.14864362802414344
# 21: 0.13513057093103947
# 22: 0.12284597357367223
# 23: 0.11167815779424747
# 24: 0.10152559799477043
# 25: 0.09229599817706402
# 26: 0.08390545288824001
# 27: 0.07627768444385455
# 28: 0.06934334949441322
# 29: 0.06303940863128474
# 30: 0.057308553301167936
# 31: 0.052098684819243575
# 32: 0.047362440744766886
# 33: 0.04305676431342444
# 34: 0.03914251301220403
# 35: 0.0355841027383673
# 36: 0.03234918430760663
# 37: 0.02940834937055148
# 38: 0.026734863064137707
# ...

# %% [markdown]
# #### Approximately everithing finishes at 1e-16
